# %% [markdown]
# <!--Header-->
# <div>
#     <div class="row" style="color: #4D4D4D;font-size: 15px;padding-bottom: 20px">
#         <div class="col-md-7">
#             <img src="http://materials.cv.uoc.edu/cdocent/common/img/logo-uoc.png" alt="Logo UOC" class="img-responsive" style="margin:20px 0px 0px">
#         </div>
#         <div class="col-md-5">
#             <h1 style="margin:15px 0px 0px;font-size: 40px;">Lectura i escriptura de fitxers de dades</h1>
#             <div style="text-align:left;margin-top: 5px;"></div>
#         </div>
#     </div>
#     <div class="row" style="background: #FCB517;padding: 10px 20px;">
#         <div class="col-md-6">
#             <div>PID_00233252</div>
#         </div>
#         <div class="col-md-6">
#             <div style="text-align:right;">Autor: Xavier Duran Albareda <span style="margin-left: 30px;">Coordinació: Julià Minguillón</span></div>
#         </div>
#     </div>
# </div>
# <!--/Header-->

# %% [markdown]
# # Introducció
#
# L'exporació, manipulació, visualització i anàlisi de dades comença amb la càrrega de les dades des de diferents formats de fitxers. En aquesta activitat veurem com llegir fitxers de tipus `CSV`, `Excel`, `TXT`, `JSON`, `XML` i `ZIP`, carregar-los en un `DataFrame` i tornar-los a guardar en un altre fitxer.

# %% [markdown]
# ![Pandas](images/pandas_logo.png)
#
# Farem servir un paquet de `Python` anomenat `Pandas`, que facilita la manipulació i l'anàlisi de dades. `Pandas` incorpora estructures de dades ràpides i flexibles dissenyades per treballar d'una manera intuitiva amb dades relacionals o etiquetades.

# %% [markdown]
# El primer que farem serà importar la llibreria `pandas`.

# %%
import pandas as pd

# %% [markdown]
# ## Fitxers CSV
#
# L'acrònim `CSV` correspon a _Comma Separated Values_, és a dir, fitxers separats per comes. De fet, veurem que la funció de `pandas` que farem servir per llegir aquests tipus de fitxers també serveix per llegir fitxers separats per altres caracters, com els `TSV` o _Tab-Separated Values_, o els fitxers separats per punt i coma.

# %% [markdown]
# El fitxer `CSV` que llegirem correspon al dataset de la competició [Titanic: Machine Learning from Disaster](https://www.kaggle.com/c/titanic) de [Kaggle](https://www.kaggle.com/).

# %% [markdown]
# Per llegir un fitxer `CSV` farem servir la funció [`read_csv`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) de `pandas`.

# %%
df = pd.read_csv("data/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Si el fitxer no té capcelera, especificarem el paràmetre `header=None` i opcionalment, el nom de les columnes.

# %%
df = pd.read_csv("data/titanic_no_header.csv", header = None,
                 names = ["PassengerId", "Survived", "Pclass", "Name",
                          "Sex", "Age", "SibSp", "Parch", "Ticket", "Fare", "Cabin", "Embarked"
                         ])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Com podem veure, el resultat és exactament el mateix, i la única diferència és que li hem hagut d'especificar explícitament el nom de les columnes.

# %% [markdown]
# Si volem llegir un fitxer que no està separat per comes, especificarem el separador amb el paràmetre `sep`.

# %%
df = pd.read_csv("data/titanic.tsv", sep='\t')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Per tornar-lo a guardar en un altre fitxer, per exemple separat per punts i coma, farem servir la funció [`to_csv`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_csv.html) de `pandas`.

# %%
df.to_csv('data/titanic_semicolon.csv', sep=';')

# %% [markdown]
# Si provem de tornar a carregar des del fitxer que hem creat just ara, veurem que ens ha creat una columna `Unnamed`. Això passa perquè per defecte ens guarda l'índex del `DataFrame`.

# %%
pd.read_csv('data/titanic_semicolon.csv', sep=';').head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Per evitar-ho, li explicitarem que no volem que ens guardi l'índex amb el paràmetre `index=False`.

# %%
df.to_csv('data/titanic_semicolon_no_index.csv', sep=';', index=False)

# %% [markdown]
# ##  Fitxers Excel
#
# Tot i ser un programari propietari, `Excel` és una de les eines més populars i utilitzades en el tractament de dades. `Pandas` és capaç de llegir els fitxers que genera aquest programari en les seves diferents versions.

# %% [markdown]
# El fitxer `Excel` que llegirem correspon al dataset de la competició [TMDB 5000 Movie Dataset](https://www.kaggle.com/tmdb/tmdb-movie-metadata) de [Kaggle](https://www.kaggle.com/).

# %% [markdown]
# Per llegir un fitxer `Excel` farem servir la funció [`read_excel`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html) de `pandas`.

# %%
xls_file = pd.read_excel('data/movies.xls')
xls_file.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings     ...      \
# 0          1.33   385907.0             NaN     ...
# 1          1.33   100000.0       3000000.0     ...
# 2          1.33   245000.0             NaN     ...
# 3          1.33  6000000.0         26435.0     ...
# 4          1.33        NaN          9950.0     ...
#
#   Facebook Likes - Actor 1 Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                      436                       22                      9.0
# 1                        2                        2                      0.0
# 2                       81                       12                      6.0
# 3                      136                       23                     18.0
# 4                      426                       20                      3.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                         481                     691                      1
# 1                           4                       0                      1
# 2                         108                     226                      0
# 3                         203                   12000                      1
# 4                         455                     926                      1
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0       10718                88                69.0         8.0
# 1           5                 1                 1.0         4.8
# 2        4849                45                48.0         8.3
# 3      111841               413               260.0         8.3
# 4        7431                84                71.0         8.0
#
# [5 rows x 25 columns]

# %% [markdown]
# El nostre `Excel` té tres `sheets`. Si no li diem res, per defecte la funció [`read_excel`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html) ens carrega el primer. Si volem especificar-ne un altre, ho podem fer pel nom amb el paràmetre `sheet_name`.

# %%
xls_file = pd.read_excel('data/movies.xls', sheet_name='2010s')
xls_file.head()
# Out:
#                                   Title    Year  \
# 0                            127 Hours   2010.0
# 1                          3 Backyards   2010.0
# 2                                    3   2010.0
# 3            8: The Mormon Proposition   2010.0
# 4  A Turtle's Tale: Sammy's Adventures   2010.0
#
#                                Genres Language  Country Content Rating  \
# 0  Adventure|Biography|Drama|Thriller  English      USA              R
# 1                               Drama  English      USA              R
# 2                Comedy|Drama|Romance   German  Germany        Unrated
# 3                         Documentary  English      USA              R
# 4          Adventure|Animation|Family  English   France             PG
#
#    Duration  Aspect Ratio      Budget  Gross Earnings     ...      \
# 0      94.0          1.85  18000000.0      18329466.0     ...
# 1      88.0           NaN    300000.0             NaN     ...
# 2     119.0          2.35         NaN         59774.0     ...
# 3      80.0          1.78   2500000.0         99851.0     ...
# 4      88.0          2.35         NaN             NaN     ...
#
#   Facebook Likes - Actor 1 Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                  11000.0                    642.0                    223.0
# 1                    795.0                    659.0                    301.0
# 2                     24.0                     20.0                      9.0
# 3                    191.0                     12.0                      5.0
# 4                    783.0                    749.0                    602.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                       11984                   63000                    0.0
# 1                        1884                      92                    0.0
# 2                          69                    2000                    0.0
# 3                         210                       0                    0.0
# 4                        3874                       0                    2.0
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0      279179             440.0               450.0         7.6
# 1         554              23.0                20.0         5.2
# 2        4212              18.0                76.0         6.8
# 3        1138              30.0                28.0         7.1
# 4        5385              22.0                56.0         6.1
#
# [5 rows x 25 columns]

# %% [markdown]
# Per tornar-lo a guardar en un altre fitxer `Excel` farem servir la funció  [`to_excel`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_excel.html) de `pandas`.

# %%
xls_file.to_excel('data/movies_2010.xlsx', index=False)

# %% [markdown]
# ## Fitxer JSON

# %% [markdown]
# [Dictionary of American Regional English (DAREDS)](https://www.kaggle.com/rtatman/dictionary-of-american-regional-english-dareds/data)

# %% [markdown]
# [Pandas JSON](https://hayd.github.io/2013/pandas-json)

# %%
import pandas as pd

df = pd.read_json('data/pandas_issues.json')
df.head(10)
# Out:
#    assignee assignees author_association  \
# 0       NaN        []              OWNER
# 1       NaN        []        CONTRIBUTOR
# 2       NaN        []               NONE
# 3       NaN        []        CONTRIBUTOR
# 4       NaN        []        CONTRIBUTOR
# 5       NaN        []        CONTRIBUTOR
# 6       NaN        []        CONTRIBUTOR
# 7       NaN        []        CONTRIBUTOR
# 8       NaN        []               NONE
# 9       NaN        []        CONTRIBUTOR
#
#                                                 body closed_at  comments  \
# 0  This adds the matplotlib.sphinxext.plot_direct...       NaT         0
# 1  xref #18614  \r\n\r\n- [ ] remove the classes,...       NaT         1
# 2  #### Code Sample, a copy-pastable example if p...       NaT         0
# 3  ```\r\npandas/tests/frame/test_operators.py::T...       NaT         0
# 4  #### Code Sample, a copy-pastable example if p...       NaT         0
# 5  This is a reopening of https://github.com/pand...       NaT         0
# 6                                                          NaT         1
# 7  #### Problem description\r\n\r\nFor long serie...       NaT         1
# 8  #### Code Sample, a copy-pastable example if p...       NaT         0
# 9  - [x] closes #19699\r\n- [x] tests added / pas...       NaT         1
#
#                                         comments_url          created_at  \
# 0  https://api.github.com/repos/pandas-dev/pandas... 2018-03-06 15:20:53
# 1  https://api.github.com/repos/pandas-dev/pandas... 2018-03-06 11:40:05
# 2  https://api.github.com/repos/pandas-dev/pandas... 2018-03-06 11:22:54
# 3  https://api.github.com/repos/pandas-dev/pandas... 2018-03-06 11:03:58
# 4  https://api.github.com/repos/pandas-dev/pandas... 2018-03-06 00:24:20
# 5  https://api.github.com/repos/pandas-dev/pandas... 2018-03-05 23:27:54
# 6  https://api.github.com/repos/pandas-dev/pandas... 2018-03-05 21:57:28
# 7  https://api.github.com/repos/pandas-dev/pandas... 2018-03-05 21:53:11
# 8  https://api.github.com/repos/pandas-dev/pandas... 2018-03-05 21:49:56
# 9  https://api.github.com/repos/pandas-dev/pandas... 2018-03-05 20:01:24
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
# 5  https://api.github.com/repos/pandas-dev/pandas...
# 6  https://api.github.com/repos/pandas-dev/pandas...
# 7  https://api.github.com/repos/pandas-dev/pandas...
# 8  https://api.github.com/repos/pandas-dev/pandas...
# 9  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url  \
# 0    https://github.com/pandas-dev/pandas/pull/20015
# 1  https://github.com/pandas-dev/pandas/issues/20014
# 2  https://github.com/pandas-dev/pandas/issues/20012
# 3  https://github.com/pandas-dev/pandas/issues/20011
# 4  https://github.com/pandas-dev/pandas/issues/20008
# 5  https://github.com/pandas-dev/pandas/issues/20007
# 6    https://github.com/pandas-dev/pandas/pull/20004
# 7  https://github.com/pandas-dev/pandas/issues/20003
# 8  https://github.com/pandas-dev/pandas/issues/20002
# 9    https://github.com/pandas-dev/pandas/pull/20000
#
#                          ...                          locked  \
# 0                        ...                           False
# 1                        ...                           False
# 2                        ...                           False
# 3                        ...                           False
# 4                        ...                           False
# 5                        ...                           False
# 6                        ...                           False
# 7                        ...                           False
# 8                        ...                           False
# 9                        ...                           False
#
#                                            milestone number  \
# 0                                               None  20015
# 1  {'url': 'https://api.github.com/repos/pandas-d...  20014
# 2                                               None  20012
# 3  {'url': 'https://api.github.com/repos/pandas-d...  20011
# 4                                               None  20008
# 5                                               None  20007
# 6                                               None  20004
# 7  {'url': 'https://api.github.com/repos/pandas-d...  20003
# 8                                               None  20002
# 9                                               None  20000
#
#                                         pull_request  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  {'url': 'https://api.github.com/repos/pandas-d...
# 7                                                NaN
# 8                                                NaN
# 9  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                    repository_url  state  \
# 0  https://api.github.com/repos/pandas-dev/pandas   open
# 1  https://api.github.com/repos/pandas-dev/pandas   open
# 2  https://api.github.com/repos/pandas-dev/pandas   open
# 3  https://api.github.com/repos/pandas-dev/pandas   open
# 4  https://api.github.com/repos/pandas-dev/pandas   open
# 5  https://api.github.com/repos/pandas-dev/pandas   open
# 6  https://api.github.com/repos/pandas-dev/pandas   open
# 7  https://api.github.com/repos/pandas-dev/pandas   open
# 8  https://api.github.com/repos/pandas-dev/pandas   open
# 9  https://api.github.com/repos/pandas-dev/pandas   open
#
#                                                title          updated_at  \
# 0  DOC: enable matplotlib plot_directive to inclu... 2018-03-06 15:21:59
# 1  CLN: followons to refactor of series/test_inde... 2018-03-06 12:14:41
# 2  Center rolling window with date NotImplemented... 2018-03-06 11:22:54
# 3                 WARN: numpy warnings on operations 2018-03-06 11:06:37
# 4  to_latex shifts column names if MultiIndex con... 2018-03-06 08:23:49
# 5          Default value for missing values on merge 2018-03-05 23:27:54
# 6       DOC: Add `Series` type to `to_sql` docstring 2018-03-05 23:51:22
# 7  PERF: isin() is slower for categorical data th... 2018-03-05 23:00:37
# 8           Splitting blank string causes exception  2018-03-05 21:55:42
# 9         API: allow list-like y argument to df.plot 2018-03-05 23:27:07
#
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
# 5  https://api.github.com/repos/pandas-dev/pandas...
# 6  https://api.github.com/repos/pandas-dev/pandas...
# 7  https://api.github.com/repos/pandas-dev/pandas...
# 8  https://api.github.com/repos/pandas-dev/pandas...
# 9  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 user
# 0  {'login': 'jorisvandenbossche', 'id': 1020496,...
# 1  {'login': 'jreback', 'id': 953992, 'avatar_url...
# 2  {'login': 'weber-s', 'id': 25247745, 'avatar_u...
# 3  {'login': 'jreback', 'id': 953992, 'avatar_url...
# 4  {'login': 'toobaz', 'id': 1224492, 'avatar_url...
# 5  {'login': 'Pastafarianist', 'id': 1315874, 'av...
# 6  {'login': 'gcbeltramini', 'id': 9801748, 'avat...
# 7  {'login': 'vfilimonov', 'id': 1324881, 'avatar...
# 8  {'login': 'montanalow', 'id': 276125, 'avatar_...
# 9  {'login': 'MasonGallo', 'id': 4913951, 'avatar...
#
# [10 rows x 23 columns]

# %%
df.to_json('output/pandas_issues.json')

# %% [markdown]
# ## Llegir un fitxer XML
#
# [Ten thousand books, one million ratings. Also books marked to read, and tags](https://www.kaggle.com/zygmunt/goodbooks-10k)

# %%
import xml.etree.ElementTree as ET

tree = ET.parse('data/sample_book.xml')
root = tree.getroot()
root.tag
# Out:
# 'GoodreadsResponse'

# %% [markdown]
# ## Llegir un fitxer zip

# %%
pd.read_csv('data/titanic-train.csv.zip', compression='infer')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male   NaN      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male   NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 0        0         A/5 21171    7.2500          NaN        S
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 4        0            373450    8.0500          NaN        S
# 5        0            330877    8.4583          NaN        Q
# 6        0             17463   51.8625          E46        S
# 7        1            349909   21.0750          NaN        S
# 8        2            347742   11.1333          NaN        S
# 9        0            237736   30.0708          NaN        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 12       0         A/5. 2151    8.0500          NaN        S
# 13       5            347082   31.2750          NaN        S
# 14       0            350406    7.8542          NaN        S
# 15       0            248706   16.0000          NaN        S
# 16       1            382652   29.1250          NaN        Q
# 17       0            244373   13.0000          NaN        S
# 18       0            345763   18.0000          NaN        S
# 19       0              2649    7.2250          NaN        C
# 20       0            239865   26.0000          NaN        S
# 21       0            248698   13.0000          D56        S
# 22       0            330923    8.0292          NaN        Q
# 23       0            113788   35.5000           A6        S
# 24       1            349909   21.0750          NaN        S
# 25       5            347077   31.3875          NaN        S
# 26       0              2631    7.2250          NaN        C
# 27       2             19950  263.0000  C23 C25 C27        S
# 28       0            330959    7.8792          NaN        Q
# 29       0            349216    7.8958          NaN        S
# ..     ...               ...       ...          ...      ...
# 861      0             28134   11.5000          NaN        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500          NaN        S
# 864      0            233866   13.0000          NaN        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 867      0          PC 17590   50.4958          A24        S
# 868      0            345777    9.5000          NaN        S
# 869      1            347742   11.1333          NaN        S
# 870      0            349248    7.8958          NaN        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000          NaN        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 876      0              7534    9.8458          NaN        S
# 877      0            349212    7.8958          NaN        S
# 878      0            349217    7.8958          NaN        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 881      0            349257    7.8958          NaN        S
# 882      0              7552   10.5167          NaN        S
# 883      0  C.A./SOTON 34068   10.5000          NaN        S
# 884      0   SOTON/OQ 392076    7.0500          NaN        S
# 885      5            382652   29.1250          NaN        Q
# 886      0            211536   13.0000          NaN        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500          NaN        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500          NaN        Q
#
# [891 rows x 12 columns]

# %%
import zipfile

zf = zipfile.ZipFile('data/titanic-train.csv.zip')
df = pd.read_csv(zf.open('titanic-train.csv'))
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male   NaN      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male   NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 0        0         A/5 21171    7.2500          NaN        S
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 4        0            373450    8.0500          NaN        S
# 5        0            330877    8.4583          NaN        Q
# 6        0             17463   51.8625          E46        S
# 7        1            349909   21.0750          NaN        S
# 8        2            347742   11.1333          NaN        S
# 9        0            237736   30.0708          NaN        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 12       0         A/5. 2151    8.0500          NaN        S
# 13       5            347082   31.2750          NaN        S
# 14       0            350406    7.8542          NaN        S
# 15       0            248706   16.0000          NaN        S
# 16       1            382652   29.1250          NaN        Q
# 17       0            244373   13.0000          NaN        S
# 18       0            345763   18.0000          NaN        S
# 19       0              2649    7.2250          NaN        C
# 20       0            239865   26.0000          NaN        S
# 21       0            248698   13.0000          D56        S
# 22       0            330923    8.0292          NaN        Q
# 23       0            113788   35.5000           A6        S
# 24       1            349909   21.0750          NaN        S
# 25       5            347077   31.3875          NaN        S
# 26       0              2631    7.2250          NaN        C
# 27       2             19950  263.0000  C23 C25 C27        S
# 28       0            330959    7.8792          NaN        Q
# 29       0            349216    7.8958          NaN        S
# ..     ...               ...       ...          ...      ...
# 861      0             28134   11.5000          NaN        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500          NaN        S
# 864      0            233866   13.0000          NaN        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 867      0          PC 17590   50.4958          A24        S
# 868      0            345777    9.5000          NaN        S
# 869      1            347742   11.1333          NaN        S
# 870      0            349248    7.8958          NaN        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000          NaN        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 876      0              7534    9.8458          NaN        S
# 877      0            349212    7.8958          NaN        S
# 878      0            349217    7.8958          NaN        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 881      0            349257    7.8958          NaN        S
# 882      0              7552   10.5167          NaN        S
# 883      0  C.A./SOTON 34068   10.5000          NaN        S
# 884      0   SOTON/OQ 392076    7.0500          NaN        S
# 885      5            382652   29.1250          NaN        Q
# 886      0            211536   13.0000          NaN        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500          NaN        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500          NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# <!--Footer-->
#  <div style="background: #333333;padding: 35px 0px;margin-top: 25px;">
#     <div class="row">
#      <div class="col-sm-12">
#         <img src="http://materials.cv.uoc.edu/cdocent/common/img/logo-uoc-bottom.png" alt="Logo UOC" class="img-responsive" style="margin: 0 auto; display: block;">
#     </div>
# </div>
# </div>
# <!--/Footer-->
